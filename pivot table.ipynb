# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/vicky/OneDrive/Desktop/titanic.csv")
df
# Out:
#       pclass  survived                                  name     sex      age  \
# 0        1.0       1.0                        Haghish, E. F.    male  30.0000
# 1        1.0       1.0         Allen, Miss. Elisabeth Walton  female  29.0000
# 2        1.0       1.0        Allison, Master. Hudson Trevor    male   0.9167
# 3        1.0       0.0          Allison, Miss. Helen Loraine  female   2.0000
# 4        1.0       0.0  Allison, Mr. Hudson Joshua Creighton    male  30.0000
# ...      ...       ...                                   ...     ...      ...
# 1306     3.0       0.0                 Zabour, Miss. Thamine  female      NaN
# 1307     3.0       0.0             Zakarian, Mr. Mapriededer    male  26.5000
# 1308     3.0       0.0                   Zakarian, Mr. Ortin    male  27.0000
# 1309     3.0       0.0                    Zimmerman, Mr. Leo    male  29.0000
# 1310     NaN       NaN                                   NaN     NaN      NaN
#
# ...

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head(n=6)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
titanic.groupby('sex')[['survived']].add()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 titanic.groupby('sex')[['survived']].add()
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'add'

# %%
titanic.groupby('sex','age')[['']]
